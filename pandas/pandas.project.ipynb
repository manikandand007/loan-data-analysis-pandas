# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\Kishore\Downloads\previous_loan.csv\previous_loan.csv")
df
# Out:
#          Unnamed: 0  reco_id_last  reco_id_curr contract_type_name  \
# 0                 0       2030495        271877     Consumer loans
# 1                 1       2802425        108129         Cash loans
# 2                 2       2523466        122040         Cash loans
# 3                 3       2819243        176158         Cash loans
# 4                 4       1784265        202054         Cash loans
# ...             ...           ...           ...                ...
# 1670209     1670209       2300464        352015     Consumer loans
# 1670210     1670210       2357031        334635     Consumer loans
# 1670211     1670211       2659632        249544     Consumer loans
# 1670212     1670212       2785582        400317         Cash loans
# 1670213     1670213       2418762        261212         Cash loans
#
#          annuity_payment  loan_body_requested  loan_body  goods_price  \
# 0               1730.430              17145.0    17145.0      17145.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Unnamed: 0                          1670214 non-null  int64
#  1   reco_id_last                        1670214 non-null  int64
#  2   reco_id_curr                        1670214 non-null  int64
#  3   contract_type_name                  1670214 non-null  object
#  4   annuity_payment                     1297979 non-null  float64
#  5   loan_body_requested                 1670214 non-null  float64
#  6   loan_body                           1670213 non-null  float64
#  7   goods_price                         1284699 non-null  float64
#  8   start_weekday_appr_process          1670214 non-null  object
#  9   hour_of_approval_process_start      1670214 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  reco_id_last  reco_id_curr  annuity_payment  \
# count  1.670214e+06  1.670214e+06  1.670214e+06     1.297979e+06
# mean   8.351065e+05  1.923089e+06  2.783572e+05     1.595512e+04
# std    4.821494e+05  5.325980e+05  1.028148e+05     1.478214e+04
# min    0.000000e+00  1.000001e+06  1.000010e+05     0.000000e+00
# 25%    4.175532e+05  1.461857e+06  1.893290e+05     6.321780e+03
# 50%    8.351065e+05  1.923110e+06  2.787145e+05     1.125000e+04
# 75%    1.252660e+06  2.384280e+06  3.675140e+05     2.065842e+04
# max    1.670213e+06  2.845382e+06  4.562550e+05     4.180581e+05
#
#        loan_body_requested     loan_body   goods_price  \
# count         1.670214e+06  1.670213e+06  1.284699e+06
# mean          1.752339e+05  1.961140e+05  2.278473e+05
# std           2.927798e+05  3.185746e+05  3.153966e+05
# min           0.000000e+00  0.000000e+00  0.000000e+00
# 25%           1.872000e+04  2.416050e+04  5.084100e+04
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                  0
# reco_id_last                                0
# reco_id_curr                                0
# contract_type_name                          0
# annuity_payment                        372235
# loan_body_requested                         0
# loan_body                                   1
# goods_price                            385515
# start_weekday_appr_process                  0
# hour_of_approval_process_start              0
# last_application_per_contract_flag          0
# last_day_app_f                              0
# down_payment_rate                      895844
# interest_privileged_rate              1664263
# cash_loan_purpose_name                      0
# contract_status_name                        0
# days_decision                               0
# payment_type_name                           0
# reject_reason_code                          0
# type_suite_name                        820405
# ...

# %%
df.drop(["interest_privileged_rate","days_first_due",],axis=1,inplace=True)

# %%
df.drop(["insured_last_f","type_suite_name","down_payment_rate","goods_price","annuity_payment","termination_date","last_due_date","first_due_date","payment_count"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                              0
# reco_id_last                            0
# reco_id_curr                            0
# contract_type_name                      0
# loan_body_requested                     0
# loan_body                               1
# start_weekday_appr_process              0
# hour_of_approval_process_start          0
# last_application_per_contract_flag      0
# last_day_app_f                          0
# cash_loan_purpose_name                  0
# contract_status_name                    0
# days_decision                           0
# payment_type_name                       0
# reject_reason_code                      0
# client_type_name                        0
# goods_category_name                     0
# portfolio_name                          0
# product_type_name                       0
# channel_type                            0
# area_seller_place                       0
# seller_industry_name                    0
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                              int64
# reco_id_last                            int64
# reco_id_curr                            int64
# contract_type_name                     object
# annuity_payment                       float64
# loan_body_requested                   float64
# loan_body                             float64
# goods_price                           float64
# start_weekday_appr_process             object
# hour_of_approval_process_start          int64
# last_application_per_contract_flag     object
# last_day_app_f                          int64
# down_payment_rate                     float64
# interest_privileged_rate              float64
# cash_loan_purpose_name                 object
# contract_status_name                   object
# days_decision                           int64
# payment_type_name                      object
# reject_reason_code                     object
# type_suite_name                        object
# ...

# %%
df.to_csv(r"C:\Users\Kishore\Downloads\previous_loan.csv\previous_loan.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Kishore\Downloads\previous_loan.csv\previous_loan.csv")
sns.barplot(data=df, x="loan_body_requested",y="channel_type",hue="contract_type_name")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Kishore\Downloads\previous_loan.csv\previous_loan.csv")
df_head = df.head(1000)
sns.scatterplot(data=df_head, x="loan_body_requested",y="reco_id_curr",hue="contract_type_name")
plt.show()

# %%
sns.barplot(data=df, x="contract_type_name",y="loan_body",hue="contract_status_name")
plt.show()

# %%
sns.lineplot(data=df, x="payment_count",y="annuity_payment",hue="client_type_name")
plt.show()
